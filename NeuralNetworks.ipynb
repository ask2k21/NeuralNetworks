# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
# Out:
# WARNING:tensorflow:From C:\Users\ASUS\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
fashion = keras.datasets.fashion_mnist
(trainImages, trainLabels), (testImages, testLabels) = fashion.load_data()

imgIndex = 0
img = trainImages[imgIndex]
print("Image Label :",trainLabels[imgIndex])
plt.imshow(img)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 1us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 5s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0s/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 1s 0us/step
# Image Label : 9

# %%
print(trainImages.shape)
print(testImages.shape)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)

# %%
model = keras.Sequential([
                          keras.layers.Flatten(input_shape=(28,28)),
                          keras.layers.Dense(128, activation=tf.nn.relu),
                          keras.layers.Dense(10, activation=tf.nn.softmax)
])
# Out:
# WARNING:tensorflow:From C:\Users\ASUS\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
model.compile(optimizer = 'adam',
           loss = 'sparse_categorical_crossentropy',
           metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\ASUS\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.fit(trainImages, trainLabels, epochs=5, batch_size=32)
# Out:
# Epoch 1/5
# WARNING:tensorflow:From C:\Users\ASUS\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\ASUS\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 1875/1875 [==============================] - 8s 4ms/step - loss: 3.6880 - accuracy: 0.6861
# Epoch 2/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.7289 - accuracy: 0.7419
# Epoch 3/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.6365 - accuracy: 0.7692
# Epoch 4/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.5524 - accuracy: 0.8052
# Epoch 5/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.5263 - accuracy: 0.8169

# %%
model.evaluate(testImages, testLabels)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.5611 - accuracy: 0.8012
# [0.5611263513565063, 0.8011999726295471]

# %%
predictions = model.predict(testImages[0:5])

# Print the predicted labels
print(predictions)
# Out:
# 1/1 [==============================] - 0s 120ms/step
# [[1.5180835e-22 2.4778299e-19 0.0000000e+00 3.9533107e-20 0.0000000e+00
#   1.4057052e-02 2.1723106e-34 5.5476174e-02 4.1394992e-18 9.3046671e-01]
#  [9.9743651e-03 4.9678251e-17 9.1464740e-01 1.5931253e-04 7.0978887e-02
#   5.5034526e-18 4.2348336e-03 0.0000000e+00 5.2700266e-06 0.0000000e+00]
#  [7.5027799e-07 9.9999928e-01 3.1978882e-14 1.4441726e-10 1.3243506e-13
#   9.6986786e-18 8.9812505e-17 0.0000000e+00 3.5605297e-13 0.0000000e+00]
#  [5.8171059e-07 9.9999940e-01 2.4014021e-14 5.2037246e-09 1.6588420e-12
#   1.0469220e-18 1.0067930e-16 0.0000000e+00 1.6827040e-12 0.0000000e+00]
#  [2.3163727e-02 7.5531756e-03 2.3237701e-01 4.3511257e-02 1.2959880e-01
#   8.6386671e-04 5.3693753e-01 1.6701682e-08 2.5994668e-02 2.8782168e-08]]

# %%
print(np.argmax(predictions, axis=1))
# Print the actual label values
print(testLabels[0:5])
# Out:
# [9 2 1 1 6]
# [9 2 1 1 6]

# %%
for i in range(0,5):
  plt.imshow(testImages[i], cmap='gray')
  plt.show()
